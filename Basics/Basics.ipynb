# %% [markdown]
# # BASIC IMAGE HANDLING AND PROCESSING WITH COMPUTER VISION LIBRARIES

# %% [markdown]
# ## PILS

# %%
from PIL import Image

#PILS object <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2022x1517 at 0x1CAE1CFF160> , not a numpy array
pil_img = Image.open('ZahaSilk.jpg') 
#Link a Synchronus Variable to the Object
sync_pil_img = pil_img 
#Create an independent copy ?????????????????

# %%
grayscale_pil_img = Image.open('ZahaSilk.jpg').convert('L')

# %%
#Create Thumbnail (Notice this is not Resize, This is Rescale to an absolute length in pixel, based on the the longer edge)
pil_img.thumbnail((128,128))  # <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x96 at 0x1CAE1CFF2B0>

# %%
#Save
Image.open('ZahaSilk.jpg').save('ZahaSilk_png.png')

# %%
#Crop
box = (100,100,400,400) # (X_upleft,Y_upleft,X_lowright,Y_lowright) . A cross vector from upleft to lowright
cropped_region = pil_img.crop(box)

# %%
#Rotate
transposed_region = cropped_region.transpose(Image.ROTATE_180)
pil_img.paste(region,box)

# %%
#Resize
resized_pil_img = pil_img.resize((128,128))

# %%
#Rotate
rotated_pil_img = pil_img.rotate(45)

# %% [markdown]
# # MATPLOTLIB

# %%
from pylab import *
array_img = array(Image.open('ZahaSilk.jpg'))

# %%
print(type(array_img))
# Out:
# <class 'numpy.ndarray'>

# %%
imshow(array_img)

# %% [markdown]
# ## Plotting on Image

# %%
x = [100,200,300,400]
y = [100,200,300,400]
plot(x,y,'r*')

# %%
plot(x[:2],y[:2]) # a line connect point 1 (100,100) and p2 (200,200)

# %%
title('Plotting Zaha')

# %%
# Line out layers, auto arranged by pylab
x = [100,200,300,400]
y = [100,200,300,400]
imshow(array_img)
plot(x,y,'r.--')  #Color:r,g,b,y,k(black),w(white),c(cyan),m(magenta) # Line: -, --, : # Marker: .,o,s (square),*,+,x
plot(x[:2],y[:2]) # a line connect point 1 (100,100) and p2 (200,200)
title('Plotting Zaha')

# %% [markdown]
# ## Color Space & Historam

# %%
img = array(Image.open('ZahaSilk.jpg').convert('L'))
#img = array(Image.open('ZahaSilk.jpg'))

# %%
figure()
gray()
contour(img,origin='image')
axis('equal')
axis('off')
# Out:
# (0.5, 2021.5, 0.5, 1516.5)

# %%
imshow(img)

# %%
figure()
print(img.shape)
flattened_img = img.flatten() 
print(flattened_img.shape)
print(img.shape)
hist(flattened_img,128)
show()
# X is bins, Y is counts
# Out:
# (1517, 2022)
# (3067374,)
# (1517, 2022)

# %% [markdown]
# ##
